# %%
library(R.matlab)
library(ggplot2)
library(fda)
library(caTools)
library(repr)
library(MASS)
# Out:
# R.matlab v3.6.1 (2016-10-19) successfully loaded. See ?R.matlab for help.
#
# Attaching package: ‘R.matlab’
#
# The following objects are masked from ‘package:base’:
#
#     getOption, isOpen
#
# Loading required package: splines
# Loading required package: Matrix
#
# Attaching package: ‘fda’
#
# The following object is masked from ‘package:graphics’:
#
#     matplot

# %%
# Change plot size to 5 x 4
options(repr.plot.width=5, repr.plot.height=4)

# %%
# Read factors for pre_pmcao
GDPC <- as.matrix(read.table("data/gdpca_factors.rmat", as.is = TRUE))
colnames(GDPC) <- NULL
GDPC <- unname(GDPC)

# %%
dim(GDPC)
# Out:
# [1] 1000  300

# %%
head(GDPC)
# Out:
#      [,1]       [,2]      [,3]       [,4]      [,5]       [,6]
# [1,] 0.05359410 -3.273232 -0.4331513 -2.789003 -0.4255449 -0.01664226
# [2,] 0.05746213 -3.096411 -0.4119083 -2.684734 -0.4475016 -0.03318929
# [3,] 0.06134977 -2.922882 -0.3905210 -2.581943 -0.4689605 -0.05073387
# [4,] 0.06522032 -2.752570 -0.3690108 -2.480910 -0.4899054 -0.06918297
# [5,] 0.06904287 -2.585525 -0.3473834 -2.381570 -0.5103329 -0.08847621
# [6,] 0.07280069 -2.422046 -0.3256544 -2.284022 -0.5302434 -0.10862200
#      [,7]       [,8]        [,9]        [,10]      [,11] [,12]     [,13]
# [1,] -0.4526101 -0.82817190 0.004697051 -0.7515082 ⋯     1.1124740 0.4627598
# [2,] -0.4637936 -0.65945260 0.049760290 -0.6993273 ⋯     1.1300390 0.4422340
# [3,] -0.4719489 -0.49656400 0.094750160 -0.6505250 ⋯     0.9880153 0.4220273
# [4,] -0.4769796 -0.33953090 0.139707900 -0.6048102 ⋯     0.8929717 0.4021161
# [5,] -0.4786678 -0.18830330 0.184642500 -0.5619907 ⋯     0.7998871 0.3825672
# ...
